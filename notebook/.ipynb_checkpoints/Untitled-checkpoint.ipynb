# %%
import pandas as pd

# %%
f = '../data/ier_2022.xlsx'
ier = pd.read_excel(f,skiprows=4)
cols = ier.columns
nombres = ['Unnamed: 0', 'nombre', 'categoria', 'TIPO \nDE \nCONTRATO',
       'RFC', 'genero', 'sni', 'VIGENCIA - SNI', 'CLAVE\nCVU',
       'EXPEDIENTE\nS N I', 'pride', 'VIGENCIA PRIDE',
       'PRIMER \nCONTRATO\nACADÉMICO', 'antiguedad',
       'ANTIGÜEDAD\nA]CADÉMICA\nDGP', 'FECHA DE NACIMIENTO', 'EDAD',
       'Observaciones']
columnas = dict(zip(columnas,nombres))
ier.rename(columns=columnas,inplace=True)
# Out:
#     Unnamed: 0                           nombre          categoria  \
# 0          1.0  ARANCIBIA BULNES CAMILO ALBERTO    INV. TIT. C. TC
# 1          2.0      ARIAS LIZÁRRAGA DULCE MARÍA  INV. ASOC. C . TC
# 2          3.0      BARRIOS DEL VALLE GUILLERMO    INV. TIT. A. TC
# 3          NaN             BEST Y BROWN ROBERTO    INV. TIT. C. TC
# 4          NaN      CUENTAS GALLEGOS ANA KARINA    INV. TIT. B. TC
# ..         ...                              ...                ...
# 85         NaN                              NaN                NaN
# 86         NaN                              NaN                NaN
# 87         NaN                              NaN                NaN
# 88         NaN                              NaN                NaN
# 89        78.0            TOTAL DE \nACADÉMICOS                NaN
#
#    TIPO \nDE \nCONTRATO            RFC genero  sni           VIGENCIA - SNI  \
# 0                   DEF  AABC690918953      H    2  01/01/2017 - 31/12/2021
# ...

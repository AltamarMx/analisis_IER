# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

# %%
f =  '../data/Seminarios2022.xlsx'
df = pd.read_excel(f)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            29 non-null     float64
#  1   Fecha                 29 non-null     datetime64[ns]
#  2   Título del seminario  29 non-null     object
#  3   Imparte               40 non-null     object
#  4   Sexo                  41 non-null     object
#  5   Origen Invitadx       40 non-null     object
#  6   Area de conocimiento  29 non-null     object
#  7   Cargo / Procedencia   29 non-null     object
#  8   Unnamed: 8            0 non-null      float64
#  9   Constancia            29 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 3.3+ KB

# %%
sns.catplot(x='Origen Invitadx',kind='count',data=df)

# %%
text = df['Area de conocimiento'].dropna().values
text = str(text)
text = text.replace(",","").replace("'","").replace('\n','')
wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
df['Sexo'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df[df['Sexo']=='Mujer']['Sexo'].count() / df[df['Sexo']=='Hombre']['Sexo'].count()
# Out:
# 1.5
